# %%
import pandas as pd

# %%
data=pd.read_csv("IDEFC_NM_oct19.csv",encoding="cp1252",thousands=',')

# %%
data["Enero"]
# Out:
# 0          3
# 1          1
# 2          0
# 3          2
# 4          0
#         ...
# 15675      8
# 15676      0
# 15677     15
# 15678      0
# 15679    132
# Name: Enero, Length: 15680, dtype: int64

# %%
data["Enero"]
# Out:
#         Año  Clave_Ent         Entidad  \
# 0      2015          1  Aguascalientes
# 1      2015          1  Aguascalientes
# 2      2015          1  Aguascalientes
# 3      2015          1  Aguascalientes
# 4      2015          1  Aguascalientes
# ...     ...        ...             ...
# 15675  2019         32       Zacatecas
# 15676  2019         32       Zacatecas
# 15677  2019         32       Zacatecas
# 15678  2019         32       Zacatecas
# 15679  2019         32       Zacatecas
#
#                                   Bien jurídico afectado  \
# 0                       La vida y la Integridad corporal
# 1                       La vida y la Integridad corporal
# 2                       La vida y la Integridad corporal
# 3                       La vida y la Integridad corporal
# 4                       La vida y la Integridad corporal
# ...                                                  ...
# 15675  Otros bienes jurídicos afectados (del fuero co...
# ...

# %%
data["Enero"].describe()
# Out:
# count    15680.000000
# mean        44.678954
# std        163.195716
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%         21.000000
# max       6270.000000
# Name: Enero, dtype: float64

# %%
data["Enero"].sum()
# Out:
# 700566

# %%
cond=(data["Subtipo de delito"]=="Homicidio doloso")&(data["Año"]==2019)&(data["Modalidad"]=="Con arma de fuego")

# %%
datos_fil=data[cond]

# %%
homi_enero=datos_fil[["Entidad","Enero"]].set_index("Entidad").sort_values("Enero",ascending=False)

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
homi_enero.plot.bar(figsize=(15,10))

# %%
homi_2019=datos_fil[["Entidad","Enero","Febrero","Marzo","Abril","Mayo","Junio","Julio","Agosto","Septiembre","Octubre","Noviembre","Diciembre"]].set_index("Entidad")

# %%
homi_2019
# Out:
#                                  Enero  Febrero  Marzo  Abril  Mayo  Junio  \
# Entidad
# Aguascalientes                       7        4      6      2     2      5
# Baja California                    183      125    132    132   173    176
# Baja California Sur                  5        2      6      6     1      0
# Campeche                             0        4      0      3     4      1
# Coahuila de Zaragoza                19       10     12     13    12      8
# Colima                              46       40     26     45    44     45
# Chiapas                             30       22     15     25    19     26
# Chihuahua                          100      115    115    123   150    138
# Ciudad de México                   104       81    108     89   116     83
# Durango                              3        7      7      8     7      3
# Guanajuato                         186      218    201    192   187    171
# ...

# %%
homi_2019.sum()
# Out:
# Enero         1763.0
# Febrero       1721.0
# Marzo         1654.0
# Abril         1608.0
# Mayo          1728.0
# Junio         1822.0
# Julio         1799.0
# Agosto        1699.0
# Septiembre    1623.0
# Octubre       1683.0
# Noviembre        0.0
# Diciembre        0.0
# dtype: float64

# %%
homi_2019.sum(axis=1).sort_values(ascending=False)
# Out:
# Entidad
# Guanajuato                         1870.0
# Baja California                    1617.0
# México                             1376.0
# Chihuahua                          1249.0
# Michoacán de Ocampo                1016.0
# Jalisco                            1010.0
# Guerrero                            985.0
# Ciudad de México                    856.0
# Veracruz de Ignacio de la Llave     737.0
# Puebla                              668.0
# Oaxaca                              654.0
# Nuevo León                          591.0
# Sonora                              570.0
# Morelos                             562.0
# Sinaloa                             462.0
# Colima                              437.0
# Tabasco                             369.0
# Quintana Roo                        332.0
# Tamaulipas                          310.0
# Zacatecas                           293.0
# San Luis Potosí                     239.0
# Chiapas                             234.0
# ...

# %%
homi_2019.to_csv("homicidios_2019_por_mes_entidad.csv")
